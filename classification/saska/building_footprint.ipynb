# %%
import geopandas as gpd

from shapely.geometry import Point


import matplotlib.pyplot as plt

% matplotlib inline

# %%
sasdf = gpd.read_file('odb_saskatchewan.shp')

# %%
sasdf.columns
# Out:
# Index(['Longitude', 'Latitude', 'CSDUID', 'CSDNAME', 'Data_prov', 'Build_ID',
#        'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
sasdf.head(20)
# Out:
#      Longitude   Latitude   CSDUID CSDNAME Data_prov        Build_ID  \
# 0  -104.625892  50.407284  4706027  Regina    Regina  47060270000001
# 1  -104.694279  50.480271  4706027  Regina    Regina  47060270000002
# 2  -104.492893  50.429645  4706027  Regina    Regina  47060270000003
# 3  -104.660338  50.460093  4706027  Regina    Regina  47060270000004
# 4  -104.650092  50.492924  4706027  Regina    Regina  47060270000005
# 5  -104.639843  50.425963  4706027  Regina    Regina  47060270000006
# 6  -104.648352  50.485615  4706027  Regina    Regina  47060270000007
# 7  -104.603447  50.414659  4706027  Regina    Regina  47060270000008
# 8  -104.588315  50.461802  4706027  Regina    Regina  47060270000009
# 9  -104.644682  50.457172  4706027  Regina    Regina  47060270000010
# 10 -104.609895  50.408780  4706027  Regina    Regina  47060270000011
# 11 -104.638735  50.472004  4706027  Regina    Regina  47060270000012
# 12 -104.552106  50.437519  4706027  Regina    Regina  47060270000013
# ...

# %%
sasdf['Data_prov'].unique()
# Out:
# array(['Regina'], dtype=object)

# %%
ax=sasdf.plot(figsize= (20, 20))
